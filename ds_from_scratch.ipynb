# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def sinplot(flip=1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)

# %%
x = np.linspace(-5,5,1000)
y = np.exp(-x**2)

sns.set_style("darkgrid")
sns.set_context("poster", font_scale=1, rc={"lines.linewidth": 4})
sns.set_palette(sns.color_palette("GnBu_d",10))
sinplot()
sns.despine()

# %%
x = np.random.normal(size=100)
sns.distplot(x, bins=30)

# %%
print x
# Out:
# [ 0.24620505 -0.78505966  0.22183169  2.25188575 -0.09052273  0.80215635
#   1.53218244  0.1494095  -0.47951672 -0.33566099 -1.43545037  0.10641783
#  -0.24879421 -1.28472314 -1.77334224 -0.45736081  0.54744837  0.73382909
#  -0.53797623  1.07906922  1.50529643 -0.25923574 -0.75852472 -1.32626271
#   0.61600794 -0.44790056 -0.72068132  0.08559584  3.74975769  2.41900515
#   1.02781371 -1.68822746  0.66767292  0.35598042 -0.99502622 -0.6607757
#  -0.90241785  0.2086492  -0.99466872 -1.14710108  0.81437981  0.6578193
#   1.52942283  1.60098115 -0.85490391  0.62627939 -0.20898518  0.26712632
#   0.61084225  0.48179828 -0.09985473 -1.18076355  0.97427512  0.21289963
#  -0.44234033 -1.7421633   1.31324178  1.79395023 -0.81507539 -0.25650159
#  -0.09125556  0.49329723 -0.50473702  0.76736532 -0.28581223  0.12677102
#  -1.63516116  0.35171364 -1.02576197  1.14844257 -1.11938361  1.65914936
#   1.36120545 -0.94661149  1.29217061 -0.66925489 -0.62142087  0.21165548
# ...

# %%
my_palette = sns.color_palette("GnBu",2)

# %%
iris = sns.load_dataset("iris")

# %%
sns.pairplot(iris)

# %%
grid = sns.PairGrid(iris)
grid.map(sns.kdeplot,n_levels=6)

# %%
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np
# Out:
# /Users/kevinsong/miniconda/envs/conda_env/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
df = pd.read_csv("https://www.ats.ucla.edu/stat/data/binary.csv")
# Out:
# ---------------------------------------------------------------------------
# CertificateError                          Traceback (most recent call last)
# <ipython-input-3-4389d278e55c> in <module>()
# ----> 1 df = pd.read_csv("https://www.ats.ucla.edu/stat/data/binary.csv")
#
# ...
